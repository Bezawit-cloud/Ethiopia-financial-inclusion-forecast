# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Load your historical and forecast data
observations = pd.read_csv("observations.csv")  # Your historical financial inclusion data
events = pd.read_csv("events.csv")              # Event-impact data
forecasts = pd.read_csv("forecasts.csv")        # Forecasted values from Task 4

# %%
st.sidebar.title("Navigation")
page = st.sidebar.radio("Go to", ["Overview", "Trends", "Forecasts", "Inclusion Projections"])
# Out:
# 2026-02-05 07:53:12.320 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:12.864
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\bezis\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-05 07:53:12.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:12.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:12.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:12.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:12.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:12.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:12.880 Session state does not function when running a script without `streamlit run`
# 2026-02-05 07:53:12.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:12.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:12.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if page == "Overview":
    st.title("Financial Inclusion Dashboard - Overview")

    # Key metrics
    latest_year = observations['Year'].max()
    acc_ownership_latest = observations.loc[observations['Year']==latest_year, 'ACC_OWNERSHIP'].values[0]
    mm_accounts_latest = observations.loc[observations['Year']==latest_year, 'ACC_MM_ACCOUNT'].values[0]
    active_rate_latest = observations.loc[observations['Year']==latest_year, 'USG_ACTIVE_RATE'].values[0]

    st.metric("Account Ownership (%)", f"{acc_ownership_latest:.1f}")
    st.metric("Mobile Money Accounts (%)", f"{mm_accounts_latest:.1f}")
    st.metric("Active Usage Rate (%)", f"{active_rate_latest:.1f}")
# Out:
# 2026-02-05 07:53:38.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 07:53:38.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if page == "Trends":
    st.title("Financial Inclusion Trends")

    # Date range selector
    min_year = int(observations['Year'].min())
    max_year = int(observations['Year'].max())
    year_range = st.slider("Select Year Range", min_year, max_year, (min_year, max_year))

    # Filter data
    obs_filtered = observations[(observations['Year'] >= year_range[0]) & (observations['Year'] <= year_range[1])]

    # Plot trend using Plotly for interactivity
    fig = px.line(
        obs_filtered, 
        x="Year", 
        y=["ACC_OWNERSHIP", "ACC_MM_ACCOUNT", "USG_ACTIVE_RATE"],
        labels={"value": "Percentage", "variable": "Indicator"},
        title="Financial Inclusion Trends"
    )
    st.plotly_chart(fig)

# %%
if page == "Forecasts":
    st.title("Financial Inclusion Forecasts (2025-2027)")

    scenario = st.selectbox("Select Scenario", ["Base", "Optimistic", "Pessimistic"])

    # Select columns based on scenario
    if scenario == "Base":
        y_cols = ["ACC_OWNERSHIP", "ACC_MM_ACCOUNT", "USG_ACTIVE_RATE"]
    elif scenario == "Optimistic":
        y_cols = ["ACC_OWNERSHIP_optimistic", "ACC_MM_ACCOUNT_optimistic", "USG_ACTIVE_RATE_optimistic"]
    else:
        y_cols = ["ACC_OWNERSHIP_pessimistic", "ACC_MM_ACCOUNT_pessimistic", "USG_ACTIVE_RATE_pessimistic"]

    fig = px.line(
        forecasts, 
        x="Year", 
        y=y_cols,
        labels={"value": "Percentage", "variable": "Indicator"},
        title=f"Forecasts: {scenario} Scenario"
    )
    st.plotly_chart(fig)

# %%
if page == "Inclusion Projections":
    st.title("Financial Inclusion Projections")

    # Progress toward 60% target
    latest_forecast = forecasts[forecasts['Year'] == 2027]['ACC_OWNERSHIP'].values[0]
    st.progress(min(int(latest_forecast), 100))
    st.write(f"Projected Account Ownership in 2027: {latest_forecast:.1f}%")
